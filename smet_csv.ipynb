# %% [markdown]
# ## .smet ASCII file to csv

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import pysumma.plotting as psp
import matplotlib.pyplot as plt

import xarray as xr
import pandas as pd
import pysumma as ps

# set how many rows pandas df shows. 
pd.set_option("min_rows", 60)

# Use pandas to read in .smet ASCII file
df = pd.read_csv('/Users/ianwhidden/pysumma/pysumma/workspace_HJA_pysumma/125_10_uplo_test.smet')
# Remove extra top rows that are outputted by MeteoIO in the .smet
df = df.iloc[16:]

# Split single column into multple columns
df = df['SMET 1.1 ASCII'].str.split(" +",expand = True)

#df['SMET 1.1 ASCII'].dtypes
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#                        0       1          2       3     4     5     6     7   \
# 16                 fields       =  timestamp      TA   TSS   TSG    VW    DW
# 17                 [DATA]    None       None    None  None  None  None  None
# 18    2021-10-02T00:00:00  289.43     273.15  273.15   3.8     0   0.0   179
# 19    2021-10-02T01:00:00  286.78     273.15  273.15   3.6     0   0.0    40
# 20    2021-10-02T02:00:00  284.12     273.15  273.15   3.5     0   0.0     0
# 21    2021-10-02T03:00:00  281.82     273.15  273.15   3.4     0   0.0     0
# 22    2021-10-02T04:00:00  280.72     273.15  273.15   3.1     0   0.0     0
# 23    2021-10-02T05:00:00  279.97     273.15  273.15   3.1     0   0.0     0
# ...

# %%
df.to_csv('smet_forcing.csv', index=False)
